# %%
import numpy as np
import librosa as lb
import sklearn as sl
import pandas as pd
import os
import librosa
import librosa.display
import matplotlib.pyplot as plt

# %%
y,sr=lb.core.load('audio3.wav')

# %%
y=y[4000:7000]
len(y)
# Out:
# 3000

# %%
t = np.arange(200)
t=np.sin(y)

# %%
plt.plot(y)

# %%
k=np.fft.fft(y)
f=np.fft.fftfreq(k.shape[-1])

# %%
plt.plot(f,k.imag,f,k.real)
plt.show()

# %%
plt.plot(abs(k))

# %%
data_fft=k
freq = (np.abs(data_fft[:len(data_fft)]))

# %%
plt.plot(freq)

# %%
f.shape
# Out:
# (3000,)

# %%
data_fft.shape
# Out:
# (3000,)

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import scipy.fftpack

# Number of samplepoints
N = 600
# sample spacing
T = 1.0 / 800.0
x = np.linspace(0.0, N*T, N)
y = np.sin(50.0 * 2.0*np.pi*x) + 0.5*np.sin(80.0 * 2.0*np.pi*x)
yf = scipy.fftpack.fft(y)
xf = np.linspace(0.0, 1.0/(2.0*T), N/2)

fig, ax = plt.subplots()
ax.plot(xf, 2.0/N * np.abs(yf[:N//2]))
plt.show()

# %%
xf.shape
# Out:
# (300,)

# %%
plt.plot(abs(k))

# %%
ab=abs(k)

# %%
max(ab)
# Out:
# 1.401937439832225
